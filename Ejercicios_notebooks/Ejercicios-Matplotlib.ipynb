# %% [markdown]
# # Ejercicios de Matplotlib
#
# Tómese su tiempo con estos ejercicios, Matplotlib puede ser difícil de entender al principio. Estas son gráficas relativamente simples, pero pueden ser difíciles si es la primera vez que usa matplotlib.
#
# No se preocupe si encuentra frustrante la sintaxis de matplotlib, en realidad no la utilizaremos con tanta frecuencia durante la asignatura, sino que también pasaremos a usar las capacidades de visualización incorporadas en seaborn y pandas. Pero, estas librerias están formadas por matplotlib, así que es importante familiarizarse con matplotlib.
#
#
# # Ejercicios
#
# Siga las instrucciones para recrear las gráficas usando esta información:
#
# ## Datos

# %%
import numpy as np
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# **Importe matplotlib.pyplot como plt y coloque ```%matplotlib inline``` en el notebook. ¿Cúal es el comando a usar si no se está sobre Jupyter notebook?**

# %% [markdown]
# ## Ejercicio 1
#
# **Siga estos pasos:**
# * **Cree un objeto "figure" llamado fig usando plt.figure()**
# * **Use "add_axes" para agregar un eje al lienzo de la figura en [0,0,1,1]. Llame a este nuevo eje *ax*.**
# * **Grafique (x, y) en esos ejes y establezca las etiquetas y títulos para que coincidan con el siguiente diagrama:**

# %%
# EL CÓDIGO AQUÍ
# REPLICAR LA IMAGEN DE LA GRÁFICA CONTINUACIÓN
# TENGA CUIDADO DE NO SOBRESCRIBIR LA CELDA DE ABAJO
# ¡QUE QUITARÍA LA IMAGEN DE LA GRÁFICA DEL EJERCICIO!

# %% [markdown]
# ## Ejercicio 2
# **Cree un objeto "figure" y coloque dos ejes sobre él: *ax1* y *ax2*, ubicados en [0,0,1,1] y [0.2,0.5, .2, .2] respectivamente.**

# %%
# EL CÓDIGO AQUÍ
# REPLICAR LA IMAGEN DE LA GRÁFICA CONTINUACIÓN
# TENGA CUIDADO DE NO SOBRESCRIBIR LA CELDA DE ABAJO
# ¡QUE QUITARÍA LA IMAGEN DE LA GRÁFICA DEL EJERCICIO!

# %% [markdown]
# **Ahora grafique (x, y) en ambos ejes. Y llame al objeto "figure" para mostrarlo.**

# %%
# EL CÓDIGO AQUÍ
# REPLICAR LA IMAGEN DE LA GRÁFICA CONTINUACIÓN
# TENGA CUIDADO DE NO SOBRESCRIBIR LA CELDA DE ABAJO
# ¡QUE QUITARÍA LA IMAGEN DE LA GRÁFICA DEL EJERCICIO!

# %% [markdown]
# ## Ejercicio 3
#
# **Cree la gráfica a continuación agregando dos ejes a un objeto "figure" en [0,0,1,1] y [0.2,0.5,.4,.4]**

# %%
# EL CÓDIGO AQUÍ
# REPLICAR LA IMAGEN DE LA GRÁFICA CONTINUACIÓN
# TENGA CUIDADO DE NO SOBRESCRIBIR LA CELDA DE ABAJO
# ¡QUE QUITARÍA LA IMAGEN DE LA GRÁFICA DEL EJERCICIO!

# %% [markdown]
# **Ahora use los arrays *x, y* y *z* para recrear la gráfica a continuación. Observe los límites sobre el eje *x* y el eje *y* en la figura mostrada:**

# %%
# EL CÓDIGO AQUÍ
# REPLICAR LA IMAGEN DE LA GRÁFICA CONTINUACIÓN
# TENGA CUIDADO DE NO SOBRESCRIBIR LA CELDA DE ABAJO
# ¡QUE QUITARÍA LA IMAGEN DE LA GRÁFICA DEL EJERCICIO!

# %% [markdown]
# ## Ejercicio 4
#
# **Use plt.subplots(nrows = 1, ncols = 2) para hacer la gráfica que se muestra a continuación.**

# %%
# EL CÓDIGO AQUÍ
# REPLICAR LA IMAGEN DE LA GRÁFICA CONTINUACIÓN
# TENGA CUIDADO DE NO SOBRESCRIBIR LA CELDA DE ABAJO
# ¡QUE QUITARÍA LA IMAGEN DE LA GRÁFICA DEL EJERCICIO!

# %% [markdown]
# **Ahora grafique (x,y) y (x,z) sobre los ejes. Juegue con los parámetros de ancho de línea (linewidth) y estilo (style)**

# %%
# EL CÓDIGO AQUÍ
# REPLICAR LA IMAGEN DE LA GRÁFICA CONTINUACIÓN
# TENGA CUIDADO DE NO SOBRESCRIBIR LA CELDA DE ABAJO
# ¡QUE QUITARÍA LA IMAGEN DE LA GRÁFICA DEL EJERCICIO!

# %% [markdown]
# **Vea si puede cambiar el tamaño de la gráfica agregando el argumento figsize() en ```plt.subplots()``` utilice su código anterior.**

# %%
# EL CÓDIGO AQUÍ
# REPLICAR LA IMAGEN DE LA GRÁFICA CONTINUACIÓN
# TENGA CUIDADO DE NO SOBRESCRIBIR LA CELDA DE ABAJO
# ¡QUE QUITARÍA LA IMAGEN DE LA GRÁFICA DEL EJERCICIO!
